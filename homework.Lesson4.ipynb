# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %% [markdown]
# 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# Математическое ожидание случайной непрерывной величины X вычисляется следующим образом: M(x) = (a+b)/2

# %%
a = 200
b = 800
Mx = (a+b)/2
Mx
# Out:
# 500.0

# %% [markdown]
# Дисперсия случайной непрерывной величины X вычисляется следующим образом: D(x) =(b-a)^2/12

# %%
Dx=((b-a)^2)/12
Dx
# Out:
# 50.166666666666664

# %% [markdown]
# 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
a = 0.5
Dx = 0.2

# %% [markdown]
# Из формулы дисперсии и математического ожидания находим правую границу:

# %%
b = (12*Dx)**0.5 + a

# %%
b
# Out:
# 2.049193338482967

# %% [markdown]
# Среднее значение будет соответствовать математическому ожиданию, поэтому:

# %%
Mx = (a+b)/2
Mx
# Out:
# 1.2745966692414834

# %%
samples = np.random.uniform(a, b, size=1000)
print(samples)
# Out:
# [1.39177987 1.6953262  1.12753005 1.37325953 1.60096192 1.32375232
#  0.98326213 1.67299948 0.87504784 1.24802483 1.27664121 0.6367472
#  1.93461837 1.2401799  1.60399077 0.7534844  1.40267807 1.60868659
#  1.09354921 1.74863715 1.72937651 1.86970041 1.71043737 1.33501293
#  1.26716829 0.69081179 0.99072546 1.86748397 1.10143139 0.87051474
#  0.79581982 1.97582415 1.9807413  0.82199294 1.93576048 1.889763
#  1.71667925 1.71846563 0.50315188 0.55055098 0.87757266 0.69623189
#  1.77633818 1.69936449 0.65151595 1.51695224 1.89305217 1.07115022
#  1.92935199 1.09342002 1.17770808 0.82228467 0.50831377 0.92117168
#  0.5028874  1.19084934 0.82184655 2.0366704  1.58710341 1.28548007
#  1.01615283 1.23772862 1.52970155 1.74524413 1.11432244 2.01526152
#  0.6457366  1.29855366 1.09492433 1.52268491 0.96278557 1.04403432
#  1.91482181 1.07074155 1.0331381  0.89051864 0.94181211 1.92481599
#  1.77086192 0.80701638 0.65379491 2.01580048 1.27442165 1.61549066
# ...

# %% [markdown]
# Математическое ожидание через numpy:

# %%
samples.mean()
# Out:
# 1.2771168951007843

# %% [markdown]
# Выборочная дисперсия (несмещённая) от выборки через numpy:

# %%
samples.var(ddof=1)
# Out:
# 0.19501395898081317

# %% [markdown]
# 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# Функция f(x) задаёт нормальный закон распределения с параметрами

# %% [markdown]
# M(x)=a=-2σ=4D(x)=σ^2=16

# %% [markdown]
# M(x)=-2D(x)=16σ =4

# %% [markdown]
# 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# Воспользуемся формулой расчета -оценки:

# %%
Z=(190-178)/np.sqrt(25)
Z
# Out:
# 2.4

# %%
print(f'Рост человека, равный 190 см, отклоняется от математического ожидания роста в популяции, \n'
      f'в которой M(X) = 178 см и D(X) = 25 кв.см на Z = {Z} сигм.')
# Out:
# Рост человека, равный 190 см, отклоняется от математического ожидания роста в популяции,
# в которой M(X) = 178 см и D(X) = 25 кв.см на Z = 2.4 сигм.
